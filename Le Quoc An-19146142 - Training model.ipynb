# %%
import cv2
import dlib
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import cv2
import mediapipe as mp
from keras.preprocessing import image
import imutils
from imutils.video import FPS

# %%
x, y = pkl.load(open('C:/Users/Admin/Downloads/samples.pkl/datasetAI.pkl', 'rb'))
print(x.shape, y.shape)
roll, pitch, yaw = y[:, 0], y[:, 1], y[:, 2]

print(roll.min(), roll.max(), roll.mean(), roll.std())
print(pitch.min(), pitch.max(), pitch.mean(), pitch.std())
print(yaw.min(), yaw.max(), yaw.mean(), yaw.std())
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (6288, 2278) (6288, 3)
# -46.06486893 43.00866699 -0.52579503197042 5.176231116713095
# -29.88856888 34.09674835 2.584682740273537 7.962828151857226
# -75.55059814 86.84925079 -0.11620588007315523 13.090839183150852
# (4401, 2278) (4401, 3)
# (943, 2278) (943, 3)
# (944, 2278) (944, 3)

# %%
std = StandardScaler()
std.fit(x_train)
x_train = std.transform(x_train)
x_val = std.transform(x_val)
x_test = std.transform(x_test)

# %%
BATCH_SIZE = 64
EPOCHS = 100

# %%
model = Sequential()
model.add(Dense(units=20, activation='relu', kernel_regularizer='l2', input_dim=x.shape[1]))
model.add(Dense(units=10, activation='relu', kernel_regularizer='l2'))
model.add(Dense(units=3, activation='linear'))

print(model.summary())

callback_list = [EarlyStopping(monitor='val_loss', patience=25)]

model.compile(optimizer='adam', loss='mean_squared_error')
hist = model.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callback_list)
model.save('models/modelface.h5')

print()
print('Train loss:', model.evaluate(x_train, y_train, verbose=0))
print('  Val loss:', model.evaluate(x_val, y_val, verbose=0))
print(' Test loss:', model.evaluate(x_test, y_test, verbose=0))

history = hist.history
loss_train = history['loss']
loss_val = history['val_loss']
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                45580
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 45,823
# Trainable params: 45,823
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 69/69 [==============================] - 1s 3ms/step - loss: 64.8810 - val_loss: 49.5218
# Epoch 2/100
# 69/69 [==============================] - 0s 2ms/step - loss: 45.4942 - val_loss: 42.5604
# Epoch 3/100
# 69/69 [==============================] - 0s 2ms/step - loss: 41.5061 - val_loss: 41.7536
# Epoch 4/100
# 69/69 [==============================] - 0s 2ms/step - loss: 38.1228 - val_loss: 39.4334
# Epoch 5/100
# 69/69 [==============================] - 0s 1ms/step - loss: 36.7285 - val_loss: 37.9404
# Epoch 6/100
# 69/69 [==============================] - 0s 2ms/step - loss: 36.0047 - val_loss: 35.8699
# Epoch 7/100
# 69/69 [==============================] - 0s 2ms/step - loss: 35.8065 - val_loss: 34.9115
# Epoch 8/100
# 69/69 [==============================] - 0s 2ms/step - loss: 34.5819 - val_loss: 35.7344
# Epoch 9/100
# 69/69 [==============================] - 0s 1ms/step - loss: 33.8165 - val_loss: 35.2053
# Epoch 10/100
# 69/69 [==============================] - 0s 2ms/step - loss: 34.1111 - val_loss: 34.7370
# Epoch 11/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.8126 - val_loss: 36.5804
# Epoch 12/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.8309 - val_loss: 34.1605
# Epoch 13/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.8911 - val_loss: 34.7642
# Epoch 14/100
# 69/69 [==============================] - 0s 1ms/step - loss: 33.7773 - val_loss: 37.8300
# Epoch 15/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.2542 - val_loss: 35.4934
# Epoch 16/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.1603 - val_loss: 37.5514
# Epoch 17/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.1571 - val_loss: 35.4674
# Epoch 18/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.2101 - val_loss: 34.0590
# Epoch 19/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.6383 - val_loss: 35.9456
# Epoch 20/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.2188 - val_loss: 34.6283
# Epoch 21/100
# 69/69 [==============================] - 0s 1ms/step - loss: 32.8308 - val_loss: 34.7513
# Epoch 22/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.4042 - val_loss: 33.9605
# Epoch 23/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.5458 - val_loss: 34.8528
# Epoch 24/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.5595 - val_loss: 33.9029
# Epoch 25/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.9560 - val_loss: 34.8198
# Epoch 26/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.0673 - val_loss: 36.0817
# Epoch 27/100
# 69/69 [==============================] - 0s 1ms/step - loss: 32.0092 - val_loss: 34.4938
# Epoch 28/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.0455 - val_loss: 34.0201
# Epoch 29/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.6879 - val_loss: 34.0559
# Epoch 30/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.8189 - val_loss: 33.6353
# Epoch 31/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.6321 - val_loss: 34.6256
# Epoch 32/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.4306 - val_loss: 35.7573
# Epoch 33/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.9632 - val_loss: 35.7767
# Epoch 34/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.0891 - val_loss: 33.6634
# Epoch 35/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.4588 - val_loss: 32.8495
# Epoch 36/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.3466 - val_loss: 34.4320
# Epoch 37/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.3900 - val_loss: 35.5802
# Epoch 38/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.0144 - val_loss: 33.8591
# Epoch 39/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.0300 - val_loss: 33.5519
# Epoch 40/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.6972 - val_loss: 33.6113
# Epoch 41/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.9698 - val_loss: 34.4440
# Epoch 42/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.4908 - val_loss: 33.7059
# Epoch 43/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.6043 - val_loss: 33.6536
# Epoch 44/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.0017 - val_loss: 33.6546
# Epoch 45/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.9996 - val_loss: 35.8518
# Epoch 46/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2975 - val_loss: 34.4975
# Epoch 47/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2045 - val_loss: 33.0742
# Epoch 48/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.0323 - val_loss: 33.5565
# Epoch 49/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.8355 - val_loss: 33.1215
# Epoch 50/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.8570 - val_loss: 32.8735
# Epoch 51/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2152 - val_loss: 33.1682
# Epoch 52/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.0145 - val_loss: 33.7357
# Epoch 53/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2739 - val_loss: 38.6407
# Epoch 54/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.8866 - val_loss: 34.7753
# Epoch 55/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.5742 - val_loss: 37.6367
# Epoch 56/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.7569 - val_loss: 34.1313
# Epoch 57/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2122 - val_loss: 35.5278
# Epoch 58/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.1743 - val_loss: 33.0792
# Epoch 59/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.6117 - val_loss: 33.5870
# Epoch 60/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.8048 - val_loss: 33.3633
#
# Train loss: 30.23833656311035
#   Val loss: 33.3632926940918
#  Test loss: 40.921836853027344

# %%
history = hist.history
loss_train = history['loss']
loss_val = history['val_loss']

plt.figure()
plt.plot(loss_train, label='train')
plt.plot(loss_val, label='val_loss', color='red')
plt.legend()

# %%
y_pred = model.predict(x_test)
diff = y_test - y_pred
diff_roll = diff[:, 0]
diff_pitch = diff[:, 1]
diff_yaw = diff[:, 2]

plt.figure(figsize=(16, 10))

plt.subplot(3, 1, 1)
plt.plot(diff_roll, color='red')
plt.title('roll')

plt.subplot(3, 1, 2)
plt.plot(diff_pitch, color='red')
plt.title('pitch')

plt.subplot(3, 1, 3)
plt.plot(diff_yaw, color='red')
plt.title('yaw')

plt.tight_layout()
# Out:
# 30/30 [==============================] - 0s 621us/step

# %%
def detect_face_points(image):
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("C:/Users/Admin/Downloads/data.dat")
    face_rect = detector(image, 1)
    if len(face_rect) != 1: return []
    
    dlib_points = predictor(image, face_rect[0])
    face_points = []
    for i in range(68):
        x, y = dlib_points.part(i).x, dlib_points.part(i).y
        face_points.append(np.array([x, y]))
    return face_points
        
def compute_features(face_points):
    assert (len(face_points) == 68), "len(face_points) must be 68"
    
    face_points = np.array(face_points)
    features = []
    for i in range(68):
        for j in range(i+1, 68):
            features.append(np.linalg.norm(face_points[i]-face_points[j]))
            
    return np.array(features).reshape(1, -1)

# %%
image = cv2.imread('C:/Users/Admin/Downloads/eeb76462bff67fa826e7.JPG', cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
face_points = detect_face_points(image)

for x, y in face_points:
    cv2.circle(image, (x, y), 1, (0, 255, 0), -1)
    
features = compute_features(face_points)
features = std.transform(features)

model = load_model('models/modelface.h5')
y_pred = model.predict(features)

roll_pred, pitch_pred, yaw_pred = y_pred[0]
print(' Z: {:.2f}°'.format(roll_pred))
print('X: {:.2f}°'.format(pitch_pred))
print('  Y: {:.2f}°'.format(yaw_pred))

plt.figure(figsize=(10, 10))
plt.imshow(image)
# Out:
# 1/1 [==============================] - 0s 203ms/step
#  Z: -1.82°
# X: 31.03°
#   Y: -27.07°

# %%
cap = cv2.VideoCapture(0)
model = load_model('C:/Users/Admin/Desktop/models/modelface.h5')
while(True):
    success, image = cap.read()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image=cv2.flip(image,1)
    face_points = detect_face_points(image)
    for x, y in face_points:
        cv2.circle(image, (x, y), 1, (0, 255, 0), -1)
    features = compute_features(face_points)
    y_pred = model.predict(features)
    roll_pred, pitch_pred, yaw_pred = y_pred[0]
    print(' Z: {:.2f}°'.format(roll_pred))
    print('X: {:.2f}°'.format(pitch_pred))
    print('  Y: {:.2f}°'.format(yaw_pred))
    if yaw_pred < -350:
        text = "Nhin ben trai"
    elif yaw_pred > 350:
        text = "Nhin ben phai"
    elif pitch_pred < -150:
        text = "Nhin xuong duoi"
    elif pitch_pred>150 :
        text = "Nhin len tren"
    elif roll_pred>-150 :
        text = "Nghieng phai"
    elif roll_pred<-260:
        text = "Nghieng trai"
    
    else:
        text = "Nhin thang"
    cv2.putText(image,"Huong nhin:" ,(100,50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(image, text, (300, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(image, 'X:'+str(np.round(pitch_pred,2)),(460,150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(image, "Y:"+str(np.round(yaw_pred,2)),(460,200), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(image, "Z:"+str(np.round(roll_pred,2)),(460,250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(image, "Goc Quay:",(460,100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.imshow('GOC XOAY KHUON MAT', image)
          
    if cv2.waitKey(1) & 0xFF == ord('q'):
         break
    
cap.release()
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\Admin\Desktop\main.ipynb Cell 10' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000009?line=7'>8</a> for x, y in face_points:
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000009?line=8'>9</a>     cv2.circle(image, (x, y), 1, (0, 255, 0), -1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000009?line=9'>10</a> features = compute_features(face_points)
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000009?line=10'>11</a> y_pred = model.predict(features)
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000009?line=11'>12</a> roll_pred, pitch_pred, yaw_pred = y_pred[0]
#
# c:\Users\Admin\Desktop\main.ipynb Cell 8' in compute_features(face_points)
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000007?line=13'>14</a> def compute_features(face_points):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000007?line=14'>15</a>     assert (len(face_points) == 68), "len(face_points) must be 68"
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000007?line=16'>17</a>     face_points = np.array(face_points)
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/main.ipynb#ch0000007?line=17'>18</a>     features = []
#
# AssertionError: len(face_points) must be 68
